# %%
2 + 2
# Out:
# 4

# %% [markdown]
# Код выше написан на Python

# %%
pwd
# Out:
# '/content'

# %%
# !ls /
# Out:
# bin	 dev   lib32   mnt			 root  sys    var
# boot	 etc   lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
# content  home  libx32  opt			 sbin  tools
# datalab  lib   media   proc			 srv   usr

# %% [markdown]
# # Настройка Git
# * настроим ник и email
# * получить токен github

# %%
# !git config --global user.name "Esya09"
# !git config --global user.email "esmirochka56@mail.ru"

# %% [markdown]
# Перейдем в папку Colab Notebook

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# Стянем репозиторий к себе на диск

# %%
# !git clone https://github.com/Emporio-Armani/programist-you.git
# Out:
# fatal: destination path 'programist-you' already exists and is not an empty directory.

# %%
# !mv conspects-IsmailovaEF.ipynb programist-you/
# Out:
# mv: cannot stat 'conspects-IsmailovaEF.ipynb': No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/programist-you
# Out:
# /content/drive/MyDrive/Colab Notebooks/programist-you

# %% [markdown]
# # Математика Python
# 1. Какие математические операции можно проводить с числами в Python?
# 2. Приведите примеры и найдите 3 отличия от классической математики. *Используйте ячейки кода и текста в Google Colab.

# %%
2 + 2 * 2 - 2 / 2
# Out:
# 5.0

# %% [markdown]
# Примеры

# %%
[x**3 for x in range(10)]
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]

# %%
lol = 'LOL' * 100
print(f'{lol} - hi')
# Out:
#  - hi

# %% [markdown]
# # Передадим файл в репозиторий

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 4 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   conspects-IsmailovaEF.ipynb

# %%
# !git commit -m "Добавил свой новый файл в репозиторий"
# Out:
# [master a9840af] Добавил свой новый файл в репозиторий
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite conspects-IsmailovaEF.ipynb (81%)

# %%
token = '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'
username = 'Emporio-Armani'
repo = 'programist-you'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Emporio-Armani/programist-you.git (fetch)
# origin	https://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@github.com/Emporio-Armani/programist-you.git (push)

# %%
# !git pull origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git push origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# # Журнал коммитов - log

# %%
# !git log
# Out:
# commit 2389984d6599508384b2b88615c31a3d5e051819 (HEAD -> master)
# Author: Esya09 <esmirochka56@mail.ru>
# Date:   Thu Feb 16 18:01:37 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 6918cfae37fd79ea364d10afaacf2a3a6529df14
# Author: Esya09 <esmirochka56@mail.ru>
# Date:   Thu Feb 16 17:39:22 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 17200e5719dea29f814a173d9e25f6d6a16b7854 (origin/master, origin/HEAD)
# Author: darinavaleeva21 <darinavaleeva21@gmail.com>
# Date:   Thu Feb 16 16:19:58 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit 377c43371fa5391edf1f7f0647e78927d05473c4
# Author: darinavaleeva21 <darinavaleeva21@gmail.com>
# Date:   Thu Feb 16 16:07:10 2023 +0000
#
#     Добавил свой новый файл в репозиторий
#
# commit b01fb7335511cb69fbbc4fb6e58fc7d7241d3358
# Author: nepoadrecy <dianamalkova2000@mail.ru>
# Date:   Wed Feb 15 23:47:59 2023 +0000
#
#     Добавил раздел log
#
# ...
